# %% [markdown]
# # Pandas Series

# %%
import pandas as pd
import numpy as np

# %%
# A series is a 1D array which store data values along with idx or labels
# basic examplpe

arr = np.array([10,20,30,40,50])
df = pd.Series(arr)

print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
