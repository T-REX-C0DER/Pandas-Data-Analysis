# %% [markdown]
# # Pandas Series

# %%
import pandas as pd
import numpy as np

# %%
# A series is a 1D array which store data values along with idx or labels

# basic examplpe
arr = np.array([10,20,30,40,50])
df = pd.Series(arr)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# series using labels
arr = np.array([10,20,30,40,50])
labels = ['a','b','c','d','e']
df = pd.Series(arr, index=labels)
print(df)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
# Series using dictionary
dict = {'a':10, 'b':20, 'c':30, 'd':40, 'e':50}
df = pd.Series(dict)
print(df)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# # Creating Data Frame

# %%
# From Dictionary 

student_data ={
    "name" : ['sanjay', 'sachin', 'suresh', 'ramesh', 'mahesh'],
    "age" : [20, 21, 22, 23, 24],
    "marks" : [80, 85, 90, 95, 100]
}

df = pd.DataFrame(student_data)
print(df)
# Out:
#      name  age  marks
# 0  sanjay   20     80
# 1  sachin   21     85
# 2  suresh   22     90
# 3  ramesh   23     95
# 4  mahesh   24    100

# %%
# From Lists 

data = [
    ['sanjay' , 20 , 99],
    ['aastha' , 20 , 100],
    ['omkar' , 19 , 95]
]
df = pd.DataFrame(data , columns=['name','age','marks'])
print(df)
# Out:
#      name  age  marks
# 0  sanjay   20     99
# 1  aastha   20    100
# 2   omkar   19     95

# %%
# From Csv & Excel

df = pd.read_csv('kantesti_global_health_insights_2025_2026.csv')
print(df)

df = pd.read_excel('data.xlsx')
print(df)
# Out:
#     country_code   country_name         region      sub_region  year  month  \
# 0             BE        Belgium         Europe  Western Europe  2025      1
# 1             BE        Belgium         Europe  Western Europe  2025      2
# 2             BE        Belgium         Europe  Western Europe  2025      3
# 3             BE        Belgium         Europe  Western Europe  2025      4
# 4             BE        Belgium         Europe  Western Europe  2025      5
# ..           ...            ...            ...             ...   ...    ...
# 125           US  United States  North America   North America  2025      9
# 126           US  United States  North America   North America  2025     10
# 127           US  United States  North America   North America  2025     11
# 128           US  United States  North America   North America  2025     12
# 129           US  United States  North America   North America  2026      1
#
#       period  monthly_analyses  cumulative_analyses  unique_users  ...  \
# 0    2025-01              7660                 7660          6718  ...
# 1    2025-02              8833                16493          7404  ...
# 2    2025-03              9412                25905          7830  ...
# 3    2025-04              8657                34562          7311  ...
# 4    2025-05             10203                44765          8520  ...
# ..       ...               ...                  ...           ...  ...
# 125  2025-09             28235               212380         23801  ...
# 126  2025-10             26394               238774         21649  ...
# 127  2025-11             31440               270214         26122  ...
# 128  2025-12             28469               298683         24150  ...
# 129  2026-01             30534               329217         25993  ...
#
#      primary_language  avg_health_score  avg_cardiovascular_risk_score  \
# 0               Dutch              69.6                           29.2
# 1               Dutch              70.2                           33.6
# 2               Dutch              72.2                           28.0
# 3               Dutch              69.8                           23.7
# 4               Dutch              70.6                           24.6
# ..                ...               ...                            ...
# 125           English              72.1                           25.4
# 126           English              70.8                           33.0
# 127           English              75.9                           24.9
# 128           English              73.9                           22.3
# 129           English              72.1                           25.0
#
#      avg_metabolic_risk_score  avg_nutrient_score  top_abnormal_biomarker_1  \
# 0                        27.1                58.7           LDL Cholesterol
# 1                        24.3                61.9           LDL Cholesterol
# 2                        20.3                59.5           LDL Cholesterol
# 3                        24.1                71.2           LDL Cholesterol
# 4                        20.5                66.3           LDL Cholesterol
# ..                        ...                 ...                       ...
# 125                      24.3                71.9           LDL Cholesterol
# 126                      31.9                61.4           LDL Cholesterol
# 127                      24.3                67.4           LDL Cholesterol
# 128                      27.0                71.2           LDL Cholesterol
# 129                      23.4                63.6           LDL Cholesterol
#
#      top_abnormal_biomarker_2  top_abnormal_biomarker_3  \
# 0                   Vitamin D                       CRP
# 1                   Vitamin D                       CRP
# 2                   Vitamin D                       CRP
# 3                   Vitamin D                       CRP
# 4                   Vitamin D                       CRP
# ..                        ...                       ...
# 125                     HbA1c             Triglycerides
# 126                     HbA1c             Triglycerides
# 127                     HbA1c             Triglycerides
# 128                     HbA1c             Triglycerides
# 129                     HbA1c             Triglycerides
#
#      avg_biomarkers_out_of_range  biomarker_abnormal_rate
# 0                            4.7                     0.40
# 1                            3.7                     0.40
# 2                            4.2                     0.39
# 3                            4.0                     0.40
# 4                            3.9                     0.36
# ..                           ...                      ...
# 125                          4.1                     0.36
# 126                          4.1                     0.34
# 127                          4.3                     0.36
# 128                          4.4                     0.36
# 129                          4.4                     0.38
#
# [130 rows x 49 columns]

# %% [markdown]
# # Selections Of Rows & Columns

# %%
# Selecting columns

print(df['name']) # selecting single column
print(df[['name','age']]) # selecting multiple columns
# Out:
# 0    sanjay
# 1    aastha
# 2     omkar
# Name: name, dtype: object
#      name  age
# 0  sanjay   20
# 1  aastha   20
# 2   omkar   19

# %%
# Selecting rows
# loc and iloc are used to select rows based on index or labels

df.loc[0] # selecting single row
df.loc[0:2] # selecting multiple rows
df.loc[0:2 , 'name'] # selecting specific column from specific rows

df.iloc[0] # selecting single row
df.iloc[0:2] # selecting multiple rows
df.iloc[0:2 , 0] # selecting specific column from specific rows
# Out:
# 0    sanjay
# 1    aastha
# Name: name, dtype: object

# %%
# Conditional selection

print(df[df['age'] >= 20]) # selecting rows based on condition
print(df[df['name'] == 'sanjay']) # selecting rows based on condition
print(df[df['marks'] >= 90]) # selecting rows based on condition
# Out:
#      name  age  marks
# 0  sanjay   20     99
# 1  aastha   20    100
#      name  age  marks
# 0  sanjay   20     99
#      name  age  marks
# 0  sanjay   20     99
# 1  aastha   20    100
# 2   omkar   19     95

# %% [markdown]
# # Updating Rows & Columns

# %%
# Updating a single value 
df.loc[0 , 'name'] = 'sanjay lade'
print(df)
# Out:
#           name  age  marks
# 0  sanjay lade   20     99
# 1       aastha   20    100
# 2        omkar   19     95

# %%
# Updating entire column
df['age'] = df['age'] + 1
print(df)
# Out:
#           name  age  marks
# 0  sanjay lade   21     99
# 1       aastha   21    100
# 2        omkar   20     95

# %%
# updating multiple rows based on condition
df.loc[df['age'] >= 20, 'age'] = df['age'] + 1
print(df)

# updating multiple columns based on condition
df.loc[df['age'] >= 20, ['age','marks']] = df.loc[df['age'] >= 20, ['age','marks']] + 1
print(df)
# Out:
#           name  age  marks
# 0  sanjay lade   24    100
# 1       aastha   24    101
# 2        omkar   23     96
#           name  age  marks
# 0  sanjay lade   25    101
# 1       aastha   25    102
# 2        omkar   24     97

# %%
# updating using .apply() method
df['age'] = df['age'].apply(lambda x : 'adult' if x >= 18 else 'minor')
print(df)

# updating using .map() method
df['age'] = df['age'].map({'adult' : 1, 'minor' : 0})
print(df)

# updating using .replace() method
df['age'] = df['age'].replace({1 : 'adult', 0 : 'minor'})
print(df)

# updating using .where() method
df['age'] = df['age'].where(df['age'] == 'adult', 'minor')
print(df)
# Out:
#           name    age  marks
# 0  sanjay lade  adult    101
# 1       aastha  adult    102
# 2        omkar  adult     97
#           name  age  marks
# 0  sanjay lade    1    101
# 1       aastha    1    102
# 2        omkar    1     97
#           name    age  marks
# 0  sanjay lade  adult    101
# 1       aastha  adult    102
# 2        omkar  adult     97
#           name    age  marks
# 0  sanjay lade  adult    101
# 1       aastha  adult    102
# 2        omkar  adult     97

# %%
# updating column 
df.rename(columns={'age' : 'age_group'}, inplace=True) # renaming column name and inplace=True is used to update the original dataframe
print(df)

df.columns = ['name', 'age_group', 'marks'] # updating column names using columns attribute
print(df)
# Out:
#      name  age_group  marks
# 0  sanjay         20     99
# 1  aastha         20    100
# 2   omkar         19     95
#      name  age_group  marks
# 0  sanjay         20     99
# 1  aastha         20    100
# 2   omkar         19     95

# %% [markdown]
# # Removing Rows & Columns

# %%
# Removing columns

# using drop()
df.drop('age_group', axis=1, inplace=True) # dropping column and inplace=True is used to update the original dataframe
print(df)

df.drop(['name','marks'], axis=1, inplace=True) # dropping multiple columns using drop() method
print(df)

# using del keyword
del df['marks'] # dropping column using del keyword
print(df)

# using pop() method
df.pop('name') # dropping column using pop() method
print(df)

# %%
# Removing rows by index
df.drop(0, axis=0, inplace=True) # dropping row by index and inplace=True is used to update the original dataframe
print(df)

df.drop([1,2], axis=0, inplace=True) # dropping multiple rows using drop() method
print(df)
# Out:
#      name  age  marks
# 1  aastha   20    100
# 2   omkar   19     95
# Empty DataFrame
# Columns: [name, age, marks]
# Index: []
