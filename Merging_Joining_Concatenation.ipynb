# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Merging data

# %%
# Data 1 
student_data = {
    "Student_ID": [101, 102, 103, 104, 105, 106, 107, 108],
    "Name": ["Amit", "Neha", "Ravi", "Pooja", "Kiran", "Sneha", "Arjun", "Meena"],
    "Branch": ["AI", "DS", "AI", "CS", "DS", "CS", "AI", "DS"],
    "Semester": [1, 1, 2, 2, 1, 2, 1, 2],
    "Marks": [78, 85, np.nan, 92, 66, 88, 74, np.nan],
    "Attendance (%)": [90, 95, 88, 98, 75, 92, np.nan, 85]
}
df1 = pd.DataFrame(student_data)
print(df1)
# Out:
#    Student_ID   Name Branch  Semester  Marks  Attendance (%)
# 0         101   Amit     AI         1   78.0            90.0
# 1         102   Neha     DS         1   85.0            95.0
# 2         103   Ravi     AI         2    NaN            88.0
# 3         104  Pooja     CS         2   92.0            98.0
# 4         105  Kiran     DS         1   66.0            75.0
# 5         106  Sneha     CS         2   88.0            92.0
# 6         107  Arjun     AI         1   74.0             NaN
# 7         108  Meena     DS         2    NaN            85.0

# %%
# Data 2
sales_data = {
    "Order_ID": [201, 202, 203, 204, 205, 206, 207, 208],
    "Product": ["Laptop", "Mouse", "Keyboard", "Laptop", "Monitor", "Mouse", "Laptop", "Keyboard"],
    "Category": ["Electronics", "Accessories", "Accessories", "Electronics", "Electronics", "Accessories", "Electronics", "Accessories"],
    "Quantity": [1, 2, 1, 1, 2, 3, 1, 2],
    "Price": [65000, 800, 1500, 70000, 12000, 850, 68000, 1600],
    "Discount (%)": [10, 5, 0, 15, np.nan, 5, 10, 0]
}
df2 = pd.DataFrame(sales_data)
print(df2)
# Out:
#    Order_ID   Product     Category  Quantity  Price  Discount (%)
# 0       201    Laptop  Electronics         1  65000          10.0
# 1       202     Mouse  Accessories         2    800           5.0
# 2       203  Keyboard  Accessories         1   1500           0.0
# 3       204    Laptop  Electronics         1  70000          15.0
# 4       205   Monitor  Electronics         2  12000           NaN
# 5       206     Mouse  Accessories         3    850           5.0
# 6       207    Laptop  Electronics         1  68000          10.0
# 7       208  Keyboard  Accessories         2   1600           0.0
